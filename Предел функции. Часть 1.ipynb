# %%
import numpy as np
from sympy import *
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 1. Предложить пример функции, не имеющей предела в нуле и в бесконечностях.

# %%
def f(x):
    if np.fabs(x) < 1:
        return np.sin(1/x)
    else:
        return np.sin(x)
    
x = np.linspace(-10, 10, 100)
y = np.array(list(map(f, x)))

plt.plot(x, y)

# %% [markdown]
# ### 2. Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %%
def f(x):
    if x < 0:
        return 0
    else:
        return 1
    
x = np.linspace(-50, 50, 100)
y = np.array(list(map(f, x)))

plt.plot(x, y)

# %% [markdown]
# ### 3. Исследовать функцию f(x)=x^3-x^2 по плану:
# Область задания и область значений
# Нули функции и их кратность
# Отрезки знакопостоянства
# Интервалы монотонности
# Четность функции
# Ограниченность
# Периодичность

# %% [markdown]
# 1) Область задания и область значений
#
# 2) Нули функции и их кратность
#
# 3) Отрезки знакопостоянства
#
# 4) Интервалы монотонности
#
# 5) Четность функции
#
# 6) Ограниченность
#
# 7) Периодичность

# %%
def f(x):
    return np.power(x, 3) - np.power(x, 2)

x = np.linspace(-50, 50, 500)
y = np.array(list(map(f, x)))

plt.plot(x, y)

# %%
x = np.linspace(-1.0001, 1.0001, 100)
y = np.array(list(map(f, x)))

plt.plot(x, y)

# %% [markdown]
# 1) Все вещественные числа
#
# 2) 0 -кратность 2 и 1
#
# 3) Отрезки знакопостоянства: от минус бесконечности до 0, от 0 до 1, от 1 до + бесконечности
#
# 4) Интервалы монотонности: от минус бесконечности до 0, от 0 до 2/3, от 2/3 до + бесконечности
#
# 5) Четность функции: ни чётная, ни нечётная
#
# 6) сверху и снизу неограничена
#
# 7) не периодична

# %% [markdown]
# ### 4.Найти предел

# %%
limit(((3*x**3) - (2*x**2))/(4*x**2), x, 0)
# Out:
# -1/2

# %%
limit(((sqrt(1 + x) - 1))/(3*sqrt((1 + x) - 1)), x, 0)
# Out:
# 0

# %% [markdown]
# ### Тема “Теоремы о пределах”

# %%
limit((sin(2*x)/4*x), x, 0)
# Out:
# 0

# %%
limit((x/sin(x)), x, 0)
# Out:
# 1

# %%
limit((x/asin(x)), x, 0)
# Out:
# 1
